# %% [markdown]
# # ECSE 415 - Assignment 5: Video Analysis
# James Rogan (ID: 261157151)
# ## Setup and Imports

# %%
import cv2
import os
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import torch

from pathlib import Path
import sklearn
import skimage
from skimage import __version__ as skimage_version
from sklearn import __version__ as sklearn_version

# =============================================================================
# CONFIGURATION: Set to True when running on Google Colab, False for local IDE
# =============================================================================
colab = True  # Set to False when running locally in IDE

# Setup paths based on environment
if colab == True:
    path = "/content/"
    A5_savepath = path
else:
    path = os.getcwd()  # Use current working directory
    A5_savepath = path  # Save outputs in current directory

# Define video paths
mp4_path_task1 = os.path.join(A5_savepath, 'task1_input.mp4')
mp4_path_task2 = os.path.join(A5_savepath, 'task2_input.mp4')

# Print configuration
print("="*70)
print("ENVIRONMENT CONFIGURATION")
print("="*70)
print(f"Running on Colab:         {'Yes' if colab else 'No'}")
print(f"Working directory:        {path}")
print(f"Save directory:           {A5_savepath}")
print(f"Task1 video path:         {mp4_path_task1}")
print(f"Task2 video path:         {mp4_path_task2}")
print("="*70)

# Print library versions
print(f"\nPython version:           {os.sys.version.split()[0]}")
print(f"OpenCV version:           {cv2.__version__}")
print(f"NumPy version:            {np.__version__}")
print(f"Matplotlib version:       {matplotlib.__version__}")
print(f"PyTorch version:          {torch.__version__}")
print(f"scikit-image version:     {skimage_version}")
print(f"scikit-learn version:     {sklearn_version}")
# Out:
# ...
# ENVIRONMENT CONFIGURATION
# ...
# Running on Colab:         Yes
# Working directory:        /content/
# Save directory:           /content/
# Task1 video path:         /content/task1_input.mp4
# Task2 video path:         /content/task2_input.mp4
# ...
#
# Python version:           3.12.12
# OpenCV version:           4.12.0
# NumPy version:            2.0.2
# Matplotlib version:       3.10.0
# PyTorch version:          2.9.0+cu126
# scikit-image version:     0.25.2
# scikit-learn version:     1.6.1

# %% [markdown]
# ## Part 1: Data Preparation
#
# Convert the images in the "Task1/images/" directory into a video at 14 FPS and save as `task1_input.mp4`.

# %%
# Download Kaggle dataset (only needed on Colab)

if colab:
    os.chdir(path)
    # !pip install kaggle

    # !mkdir -p ~/.kaggle

    # Get credentials from Colab Secrets and create kaggle.json
    kaggle_username = "jamesrogan5"
    kaggle_key = "b60df8e8c8a3f344b206406bf815c127"

    import json
    kaggle_creds = {
        "username": kaggle_username,
        "key": kaggle_key
    }

    with open('/root/.kaggle/kaggle.json', 'w') as f:
        json.dump(kaggle_creds, f)

    # !chmod 600 ~/.kaggle/kaggle.json

    # Download and extract dataset
    # !kaggle competitions download -c ecse-415-video-analysis
    # !unzip -q ecse-415-video-analysis.zip -d .
    print("✓ Kaggle dataset downloaded and extracted")
else:
    print("Running locally - assuming dataset is already in working directory")
    print(f"Expected data location: {os.path.join(path, 'Object_Tracking')}")
# Out:
# ...
# ecse-415-video-analysis.zip: Skipping, found more recently modified local copy (use --force to force download)
# replace ./Object_Tracking/Task1/gt/gt.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ✓ Kaggle dataset downloaded and extracted

# %%
# Convert Task1 images to video at 14 FPS

task1_dir = Path(path, "Object_Tracking", "Task1")
csv1_path = Path(task1_dir, "gt", "gt.txt")
ground_truth_task1 = np.loadtxt(csv1_path, delimiter=",")

images1_path = Path(task1_dir, "images")

# Get all image files and sort them by filename to ensure correct order
image_files = sorted([f for f in os.listdir(images1_path) if f.endswith(('.jpg', '.png', '.jpeg'))])

print(f"Found {len(image_files)} images in {images1_path}")

if len(image_files) == 0:
    print("ERROR: No images found!")
else:
    # Read first image to get dimensions
    first_img_path = Path(images1_path, image_files[0])
    first_frame = cv2.imread(str(first_img_path))
    H, W, _ = first_frame.shape

    print(f"Video dimensions: {W}x{H}")

    # Set up VideoWriter with 14 FPS (as required)
    fps = 14.0
    frame_size = (W, H)

    # Try different codecs for better compatibility
    codecs_to_try = [
        ('avc1', 'H.264 (avc1)'),
        ('H264', 'H.264 (H264)'),
        ('X264', 'H.264 (X264)'),
        ('mp4v', 'MPEG-4'),
        ('XVID', 'XVID')
    ]

    writer = None
    codec_used = None

    for codec, codec_name in codecs_to_try:
        fourcc = cv2.VideoWriter_fourcc(*codec)
        test_writer = cv2.VideoWriter(mp4_path_task1, fourcc, fps, frame_size)
        if test_writer.isOpened():
            writer = test_writer
            codec_used = codec_name
            print(f"Using codec: {codec_name}")
            break
        else:
            test_writer.release()

    if writer is None or not writer.isOpened():
        print("ERROR: Could not open VideoWriter with any codec!")
    else:
        # Write all frames to video
        frame_count = 0
        for img_file in image_files:
            img_path = Path(images1_path, img_file)
            img_bgr = cv2.imread(str(img_path))

            if img_bgr is not None:
                # Ensure frame is correct size
                if img_bgr.shape[:2] != (H, W):
                    img_bgr = cv2.resize(img_bgr, (W, H))

                # cv2.VideoWriter expects BGR format
                writer.write(img_bgr)
                frame_count += 1
            else:
                print(f"Warning: Could not read {img_file}")

        # Release the writer
        writer.release()

        # Verify file was created
        if os.path.exists(mp4_path_task1):
            file_size_mb = os.path.getsize(mp4_path_task1) / (1024 * 1024)
            print(f"\n✓ Part 1 Complete: Video created successfully!")
            print(f"  Output: {mp4_path_task1}")
            print(f"  Codec: {codec_used}")
            print(f"  Frames written: {frame_count}/{len(image_files)}")
            print(f"  FPS: {fps}")
            print(f"  Duration: {frame_count/fps:.2f} seconds")
            print(f"  File size: {file_size_mb:.2f} MB")
        else:
            print("ERROR: Video file was not created!")
# Out:
# Found 429 images in /content/Object_Tracking/Task1/images
# Video dimensions: 1920x1080
# Using codec: MPEG-4
#
# ✓ Part 1 Complete: Video created successfully!
#   Output: /content/task1_input.mp4
#   Codec: MPEG-4
#   Frames written: 429/429
#   FPS: 14.0
#   Duration: 30.64 seconds
#   File size: 30.90 MB

# %% [markdown]
# ## Part 2: Model Implementation
#
# - Apply DeepSORT with YOLOv8 to detect and track pedestrians in the video.
# - Save the output video as `task1.mp4`
# - Save tracking results in the format: `<frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>`

# %%
# Install required packages for YOLOv8 + DeepSORT

# Install ultralytics (YOLOv8)
# !pip install ultralytics

# Install deep-sort-realtime
# !pip install deep-sort-realtime

print("✓ Packages installed successfully!")
# Out:
# ...
# ✓ Packages installed successfully!

# %%
# YOLOv8 + DeepSORT Tracking Implementation

from ultralytics import YOLO
from deep_sort_realtime.deepsort_tracker import DeepSort

# Initialize YOLOv8 model
print("Loading YOLOv8 model...")
model = YOLO('yolov8n.pt')  # Using nano model for speed, can use yolov8s.pt, yolov8m.pt for better accuracy
print("✓ YOLOv8 model loaded")

# Initialize DeepSORT tracker
print("Initializing DeepSORT tracker...")
tracker = DeepSort(
    max_age=30,           # Maximum frames to keep track alive without detections
    n_init=3,             # Number of consecutive frames for track confirmation
    max_iou_distance=0.7, # Maximum IOU distance for matching
    embedder="mobilenet", # Feature extractor
    half=True,            # Use FP16 for speed
    embedder_gpu=torch.cuda.is_available()
)
print("✓ DeepSORT tracker initialized")

# Open input video
cap = cv2.VideoCapture(mp4_path_task1)

# Get video properties
fps_input = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"\nInput Video Properties:")
print(f"  Resolution: {width}x{height}")
print(f"  FPS: {fps_input}")
print(f"  Total frames: {total_frames}")

# Set up output paths
output_path = os.path.join(A5_savepath, 'task1.mp4')
tracking_results_path = os.path.join(A5_savepath, 'task1_tracking.txt')

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps_input, (width, height))

# Open file to save tracking results
tracking_file = open(tracking_results_path, 'w')

# Process video frame by frame
frame_idx = 0
tracking_data = []

print("\nProcessing video with YOLOv8 + DeepSORT...")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_idx += 1

    # Run YOLOv8 detection (class 0 is 'person' in COCO dataset)
    results = model(frame, classes=[0], verbose=False)  # Only detect persons

    # Extract detections for DeepSORT
    detections = []
    for result in results:
        boxes = result.boxes
        for box in boxes:
            # Get bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
            conf = box.conf[0].cpu().numpy()

            # Convert to [left, top, width, height] format for DeepSORT
            bbox = [x1, y1, x2 - x1, y2 - y1]

            # DeepSORT expects: ([left, top, width, height], confidence, class_name)
            detections.append((bbox, conf, 'person'))

    # Update tracker with detections
    tracks = tracker.update_tracks(detections, frame=frame)

    # Draw bounding boxes and IDs on frame
    for track in tracks:
        if not track.is_confirmed():
            continue

        track_id = track.track_id
        ltrb = track.to_ltrb()  # Get [left, top, right, bottom]

        x1, y1, x2, y2 = map(int, ltrb)
        bb_left = x1
        bb_top = y1
        bb_width = x2 - x1
        bb_height = y2 - y1

        # Save tracking result: <frame>, <id>, <bb_left>, <bb_top>, <bb_width>, <bb_height>
        tracking_file.write(f"{frame_idx},{track_id},{bb_left},{bb_top},{bb_width},{bb_height}\n")
        tracking_data.append([frame_idx, track_id, bb_left, bb_top, bb_width, bb_height])

        # Draw bounding box
        cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

        # Draw tracking ID
        label = f'ID: {track_id}'
        label_size, _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)
        label_y = max(y1 - 10, label_size[1] + 10)

        # Draw background for text
        cv2.rectangle(frame, (x1, label_y - label_size[1] - 10),
                     (x1 + label_size[0], label_y), (0, 255, 0), -1)

        # Draw text
        cv2.putText(frame, label, (x1, label_y - 5),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 2)

    # Add frame number to video
    cv2.putText(frame, f'Frame: {frame_idx}/{total_frames}', (10, 30),
               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    # Write frame to output video
    out.write(frame)

    # Progress indicator
    if frame_idx % 50 == 0:
        print(f"  Processed frame {frame_idx}/{total_frames} ({frame_idx/total_frames*100:.1f}%)")

# Release resources
cap.release()
out.release()
tracking_file.close()

print(f"\n✓ Part 2 Complete!")
print(f"  Output video: {output_path}")
print(f"  Tracking results: {tracking_results_path}")
print(f"  Total frames processed: {frame_idx}")
print(f"  Total tracked detections: {len(tracking_data)}")
# Out:
# Loading YOLOv8 model...
# ...
# ✓ YOLOv8 model loaded
# Initializing DeepSORT tracker...
# ✓ DeepSORT tracker initialized
#
# Input Video Properties:
#   Resolution: 1920x1080
#   FPS: 14.0
#   Total frames: 429
#
# Processing video with YOLOv8 + DeepSORT...
#   Processed frame 50/429 (11.7%)
#   Processed frame 100/429 (23.3%)
#   Processed frame 150/429 (35.0%)
#   Processed frame 200/429 (46.6%)
#   Processed frame 250/429 (58.3%)
#   Processed frame 300/429 (69.9%)
#   Processed frame 350/429 (81.6%)
#   Processed frame 400/429 (93.2%)
#
# ✓ Part 2 Complete!
#   Output video: /content/task1.mp4
#   Tracking results: /content/task1_tracking.txt
#   Total frames processed: 429
#   Total tracked detections: 12851

# %%
# Display Tracking Statistics and Sample Frame

import pandas as pd

# Load tracking results
tracking_df = pd.DataFrame(tracking_data, columns=['frame', 'id', 'bb_left', 'bb_top', 'bb_width', 'bb_height'])

print("="*60)
print("TRACKING STATISTICS")
print("="*60)
print(f"Total detections:              {len(tracking_df)}")
print(f"Unique track IDs:              {tracking_df['id'].nunique()}")
print(f"Frames with detections:        {tracking_df['frame'].nunique()}")
print(f"Average detections per frame:  {len(tracking_df) / tracking_df['frame'].nunique():.2f}")
print("="*60)

# Show distribution of track IDs
print("\nTop 10 Most Frequent Track IDs:")
print(tracking_df['id'].value_counts().head(10))

# Display a sample tracked frame from the middle of the video
sample_frame_num = total_frames // 2
cap_sample = cv2.VideoCapture(output_path)
cap_sample.set(cv2.CAP_PROP_POS_FRAMES, sample_frame_num - 1)
ret, sample_frame = cap_sample.read()
cap_sample.release()

if ret:
    # Convert BGR to RGB for matplotlib
    sample_frame_rgb = cv2.cvtColor(sample_frame, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(12, 8))
    plt.imshow(sample_frame_rgb)
    plt.title(f'Sample Tracked Frame (Frame {sample_frame_num})')
    plt.axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# ...
# TRACKING STATISTICS
# ...
# Total detections:              12851
# Unique track IDs:              97
# Frames with detections:        427
# Average detections per frame:  30.10
# ...
#
# Top 10 Most Frequent Track IDs:
# id
# 8     427
# 13    427
# 22    422
# 25    420
# 46    399
# 4     388
# 10    371
# 6     370
# 3     346
# 1     342
# Name: count, dtype: int64

# %% [markdown]
# ## Part 3: Model Evaluation
#
# **Objective:** Evaluate the tracker using the Multiple Object Tracking Accuracy (MOTA) metric.
#
# **MOTA Formula:**
# ```
# MOTA = 1 - Σ(FN + FP + IDSW) / Σ(GT)
# ```
#
# **Implementation Details:**
# - Use IoU ≥ 0.5 to match predicted bounding boxes with ground-truth boxes
# - Implement the Hungarian Algorithm to find optimal assignments
# - Track False Positives (FP), False Negatives (FN), and Identity Switches (IDSW)

# %%
# Helper Functions for MOTA Calculation

from scipy.optimize import linear_sum_assignment

def compute_iou(box1, box2):
    """
    Compute IoU between two bounding boxes.
    Box format: [x, y, width, height]
    """
    x1_min = box1[0]
    y1_min = box1[1]
    x1_max = box1[0] + box1[2]
    y1_max = box1[1] + box1[3]

    x2_min = box2[0]
    y2_min = box2[1]
    x2_max = box2[0] + box2[2]
    y2_max = box2[1] + box2[3]

    overlap_x_min = max(x1_min, x2_min)
    overlap_y_min = max(y1_min, y2_min)
    overlap_x_max = min(x1_max, x2_max)
    overlap_y_max = min(y1_max, y2_max)

    overlap_width = overlap_x_max - overlap_x_min
    overlap_height = overlap_y_max - overlap_y_min

    if overlap_width <= 0 or overlap_height <= 0:
        return 0.0

    intersection_area = overlap_width * overlap_height
    union_area = box1[2] * box1[3] + box2[2] * box2[3] - intersection_area

    return intersection_area / union_area


def compute_iou_one_frame(gt_boxes, pred_boxes):
    """
    Compute IoU matrix for all GT and predicted boxes in a frame.
    Returns: IoU matrix (rows=GT, cols=Pred)
    """
    matrix = np.zeros((len(gt_boxes), len(pred_boxes)))
    for i, gt_box in enumerate(gt_boxes):
        for j, pred_box in enumerate(pred_boxes):
            matrix[i, j] = compute_iou(gt_box, pred_box)
    return matrix


def match_boxes(gt_boxes, pred_boxes, iou_threshold=0.5):
    """
    Match GT boxes to predicted boxes using Hungarian algorithm.
    Returns: matches, unmatched_gt, unmatched_pred
    """
    # Handle edge cases
    if len(gt_boxes) == 0 or len(pred_boxes) == 0:
        return [], list(range(len(gt_boxes))), list(range(len(pred_boxes)))

    # Compute IoU matrix
    iou_matrix = compute_iou_one_frame(gt_boxes, pred_boxes)

    # Hungarian algorithm (minimizes cost, so negate IoU)
    cost_matrix = -iou_matrix
    gt_indices, pred_indices = linear_sum_assignment(cost_matrix)

    # Filter matches by IoU threshold
    matches = []
    matched_gt = set()
    matched_pred = set()

    for gt_idx, pred_idx in zip(gt_indices, pred_indices):
        iou = iou_matrix[gt_idx, pred_idx]
        if iou >= iou_threshold:
            matches.append((gt_idx, pred_idx, iou))
            matched_gt.add(gt_idx)
            matched_pred.add(pred_idx)

    # Find unmatched boxes
    unmatched_gt = [i for i in range(len(gt_boxes)) if i not in matched_gt]
    unmatched_pred = [i for i in range(len(pred_boxes)) if i not in matched_pred]

    return matches, unmatched_gt, unmatched_pred

# %%
# Calculate MOTA Score

print("Loading data for MOTA evaluation...")

# Load ground truth data
gt_data = ground_truth_task1  # Already loaded in Part 1
print(f"  Ground truth: {len(gt_data)} detections")

# Load prediction data
pred_path = os.path.join(A5_savepath, 'task1_tracking.txt')
pred_data = np.loadtxt(pred_path, delimiter=',')
print(f"  Predictions: {len(pred_data)} detections")

# Get frame range
max_frame = int(max(gt_data[:, 0].max(), pred_data[:, 0].max()))
min_frame = 1
print(f"  Frame range: {min_frame} to {max_frame}")

# Initialize counters
total_FN = 0
total_FP = 0
total_IDSW = 0
total_GT = 0

# Track GT object IDs across frames for identity switch detection
# Maps: gt_id -> pred_id from previous frame
gt_to_pred_id = {}

print("\nProcessing frames for MOTA evaluation...")

# Process each frame
for frame_num in range(min_frame, max_frame + 1):
    # Get boxes for this frame
    gt_frame = gt_data[gt_data[:, 0] == frame_num]
    pred_frame = pred_data[pred_data[:, 0] == frame_num]

    # Extract box coordinates [x, y, w, h]
    gt_boxes = gt_frame[:, 2:6]  # columns: bb_left, bb_top, bb_width, bb_height
    pred_boxes = pred_frame[:, 2:6]

    # Extract IDs
    gt_ids = gt_frame[:, 1] if len(gt_frame) > 0 else []
    pred_ids = pred_frame[:, 1] if len(pred_frame) > 0 else []

    # Match boxes using Hungarian algorithm
    matches, unmatched_gt, unmatched_pred = match_boxes(gt_boxes, pred_boxes, iou_threshold=0.5)

    # Count false negatives and false positives
    FN = len(unmatched_gt)
    FP = len(unmatched_pred)
    GT = len(gt_boxes)

    total_FN += FN
    total_FP += FP
    total_GT += GT

    # Count identity switches
    IDSW = 0
    for gt_idx, pred_idx, iou in matches:
        gt_id = gt_ids[gt_idx]
        pred_id = pred_ids[pred_idx]

        # Check if this GT object was tracked before
        if gt_id in gt_to_pred_id:
            # If it was matched to a different prediction ID, it's an identity switch
            if gt_to_pred_id[gt_id] != pred_id:
                IDSW += 1

        # Update tracking
        gt_to_pred_id[gt_id] = pred_id

    total_IDSW += IDSW

    # Progress indicator
    if frame_num % 50 == 0:
        print(f"  Processed frame {frame_num}/{max_frame}")

# Calculate MOTA
if total_GT > 0:
    MOTA = 1 - (total_FN + total_FP + total_IDSW) / total_GT
else:
    MOTA = 0.0

# Display results
print("\n" + "="*60)
print("PART 3: MOTA EVALUATION RESULTS")
print("="*60)
print(f"False Negatives (FN):      {total_FN}")
print(f"False Positives (FP):      {total_FP}")
print(f"Identity Switches (IDSW):  {total_IDSW}")
print(f"Ground Truth Objects (GT): {total_GT}")
print("-"*60)
print(f"MOTA Score: {MOTA:.4f} ({MOTA*100:.2f}%)")
print("="*60)

# Additional statistics
print("\nDetailed Breakdown:")
print(f"  Miss Rate (FN/GT):        {total_FN/total_GT:.2%}" if total_GT > 0 else "  Miss Rate: N/A")
print(f"  False Alarm Rate (FP/GT): {total_FP/total_GT:.2%}" if total_GT > 0 else "  False Alarm Rate: N/A")
print(f"  ID Switch Rate (IDSW/GT): {total_IDSW/total_GT:.2%}" if total_GT > 0 else "  ID Switch Rate: N/A")
# Out:
# Loading data for MOTA evaluation...
#   Ground truth: 26647 detections
#   Predictions: 12851 detections
#   Frame range: 1 to 429
#
# Processing frames for MOTA evaluation...
#   Processed frame 50/429
#   Processed frame 100/429
#   Processed frame 150/429
#   Processed frame 200/429
#   Processed frame 250/429
#   Processed frame 300/429
#   Processed frame 350/429
#   Processed frame 400/429
#
# ...
# PART 3: MOTA EVALUATION RESULTS
# ...
# False Negatives (FN):      16979
# False Positives (FP):      3183
# Identity Switches (IDSW):  436
# Ground Truth Objects (GT): 26647
# ------------------------------------------------------------
# MOTA Score: 0.2270 (22.70%)
# ...
#
# Detailed Breakdown:
#   Miss Rate (FN/GT):        63.72%
#   False Alarm Rate (FP/GT): 11.95%
#   ID Switch Rate (IDSW/GT): 1.64%

# %%
# Visualize MOTA Results

import matplotlib.pyplot as plt

# Create visualization
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Error breakdown (counts)
error_types = ['False\nNegatives', 'False\nPositives', 'Identity\nSwitches']
error_counts = [total_FN, total_FP, total_IDSW]
colors = ['#ff6b6b', '#feca57', '#48dbfb']

axes[0].bar(error_types, error_counts, color=colors)
axes[0].set_ylabel('Count')
axes[0].set_title('Error Breakdown (Absolute Counts)')
axes[0].grid(axis='y', alpha=0.3)

for i, count in enumerate(error_counts):
    axes[0].text(i, count + max(error_counts)*0.02, str(count),
                ha='center', va='bottom', fontweight='bold')

# Plot 2: Error rates as percentages
if total_GT > 0:
    percentages = [
        total_FN / total_GT * 100,
        total_FP / total_GT * 100,
        total_IDSW / total_GT * 100
    ]

    axes[1].bar(error_types, percentages, color=colors)
    axes[1].set_ylabel('Percentage of GT (%)')
    axes[1].set_title('Error Rates (Relative to GT)')
    axes[1].grid(axis='y', alpha=0.3)

    for i, pct in enumerate(percentages):
        axes[1].text(i, pct + max(percentages)*0.02, f'{pct:.1f}%',
                    ha='center', va='bottom', fontweight='bold')

plt.tight_layout()
plt.show()

# Summary table
print("\n" + "="*60)
print("SUMMARY TABLE")
print("="*60)
print(f"{'Metric':<30} {'Count':<15} {'% of GT':<15}")
print("="*60)
if total_GT > 0:
    print(f"{'False Negatives (FN)':<30} {total_FN:<15} {total_FN/total_GT*100:>6.2f}%")
    print(f"{'False Positives (FP)':<30} {total_FP:<15} {total_FP/total_GT*100:>6.2f}%")
    print(f"{'Identity Switches (IDSW)':<30} {total_IDSW:<15} {total_IDSW/total_GT*100:>6.2f}%")
    print(f"{'Ground Truth (GT)':<30} {total_GT:<15} {'100.00%':>11}")
    print("="*60)
    print(f"{'MOTA Score':<30} {MOTA:<15.4f} {MOTA*100:>6.2f}%")
print("="*60)
# Out:
# ...
# SUMMARY TABLE
# ...
# Metric                         Count           % of GT
# ...
# False Negatives (FN)           16979            63.72%
# False Positives (FP)           3183             11.95%
# Identity Switches (IDSW)       436               1.64%
# Ground Truth (GT)              26647               100.00%
# ...
# MOTA Score                     0.2270           22.70%
# ...

# %% [markdown]
# ## Part 4: Prediction & Kaggle Competition
#
# **Objective:** Apply tracking to Task2 dataset and generate pedestrian count predictions for Kaggle submission.
#
# **Steps:**
# 1. Convert Task2 images to video
# 2. Apply improved tracking method (recommended: YOLOv8 + BoTSORT or ByteTrack)
# 3. Save annotated video as `task2.mp4`
# 4. Count pedestrians per frame
# 5. Export counts to `task2_count.csv` for Kaggle submission
#
# **CSV Format:**
# ```
# Number,Count
# 1,12
# 2,15
# ...
# ```

# %%
# =============================================================================
# TASK 2 CONFIGURATION - Tune these parameters to improve performance
# =============================================================================

# Model Selection (choose one):
# - 'yolov8n.pt'  : Nano   (fastest, lowest accuracy)
# - 'yolov8s.pt'  : Small
# - 'yolov8m.pt'  : Medium
# - 'yolov8l.pt'  : Large  (slower, higher accuracy)
# - 'yolov8x.pt'  : XLarge (slowest, highest accuracy)
TASK2_MODEL = 'yolov8x.pt'  # MAXIMUM ACCURACY

# Detection Parameters
TASK2_CONF_THRESHOLD = 0.01   # Confidence threshold (0.0-1.0)
                              # Lower = more detections (more false positives)
                              # Higher = fewer detections (more false negatives)
                              # LOWERED for maximum recall

TASK2_IOU_THRESHOLD = 0.7     # IOU threshold for NMS (0.0-1.0)
                              # Lower = more aggressive NMS (fewer overlapping boxes)
                              # Higher = less aggressive NMS (more overlapping boxes)
                              # LOWERED for better detection in crowds

# Tracker Selection:
# - 'botsort.yaml'  : BoT-SORT (better for crowded scenes)
# - 'bytetrack.yaml': ByteTrack (faster, good for general use)
TASK2_TRACKER = 'botsort.yaml'  # Best for crowded scenes

# Image Size for Inference
TASK2_IMGSZ = 1920            # Image size for inference (None = auto)
                              # INCREASED for better small object detection

# Advanced YOLO Parameters (optional)
TASK2_AUGMENT = True          # Use test-time augmentation (slower but more robust)
                              # ENABLED for maximum accuracy
TASK2_AGNOSTIC_NMS = False    # Class-agnostic NMS
TASK2_MAX_DET = 500           # Maximum number of detections per image
                              # INCREASED for very crowded scenes

# Video FPS
TASK2_VIDEO_FPS = 14.0       # FPS for Task2 video creation

print("="*70)
print("TASK 2 CONFIGURATION - MAXIMUM ACCURACY MODE")
print("="*70)
print(f"Model:              {TASK2_MODEL}")
print(f"Confidence:         {TASK2_CONF_THRESHOLD} (Lower = more detections)")
print(f"IOU Threshold:      {TASK2_IOU_THRESHOLD} (Lower = better for crowds)")
print(f"Tracker:            {TASK2_TRACKER}")
print(f"Image Size:         {TASK2_IMGSZ if TASK2_IMGSZ else 'Auto'}")
print(f"Augment:            {TASK2_AUGMENT} (Slower but more robust)")
print(f"Max Detections:     {TASK2_MAX_DET}")
print(f"Video FPS:          {TASK2_VIDEO_FPS}")
# Out:
# ...
# TASK 2 CONFIGURATION - MAXIMUM ACCURACY MODE
# ...
# Model:              yolov8x.pt
# Confidence:         0.01 (Lower = more detections)
# IOU Threshold:      0.7 (Lower = better for crowds)
# Tracker:            botsort.yaml
# Image Size:         1920
# Augment:            True (Slower but more robust)
# Max Detections:     500
# Video FPS:          14.0

# %%
# Step 1: Convert Task2 images to video

task2_dir = Path(path, "Object_Tracking", "Task2")
images2_path = Path(task2_dir, "images")

# Get all image files and sort them
image_files_task2 = sorted([f for f in os.listdir(images2_path) if f.endswith(('.jpg', '.png', '.jpeg'))])

print(f"Found {len(image_files_task2)} images in {images2_path}")

if len(image_files_task2) == 0:
    print("ERROR: No images found!")
else:
    # Read first image to get dimensions
    first_img_path = Path(images2_path, image_files_task2[0])
    first_frame = cv2.imread(str(first_img_path))
    H, W, _ = first_frame.shape

    print(f"Video dimensions: {W}x{H}")

    # Use configured FPS
    frame_size = (W, H)

    # Try different codecs
    codecs_to_try = [
        ('avc1', 'H.264 (avc1)'),
        ('H264', 'H.264 (H264)'),
        ('X264', 'H.264 (X264)'),
        ('mp4v', 'MPEG-4'),
        ('XVID', 'XVID')
    ]

    writer = None
    codec_used = None

    for codec, codec_name in codecs_to_try:
        fourcc = cv2.VideoWriter_fourcc(*codec)
        test_writer = cv2.VideoWriter(mp4_path_task2, fourcc, TASK2_VIDEO_FPS, frame_size)
        if test_writer.isOpened():
            writer = test_writer
            codec_used = codec_name
            print(f"Using codec: {codec_name}")
            break
        else:
            test_writer.release()

    if writer is None or not writer.isOpened():
        print("ERROR: Could not open VideoWriter with any codec!")
    else:
        # Write all frames to video
        frame_count = 0
        for img_file in image_files_task2:
            img_path = Path(images2_path, img_file)
            img_bgr = cv2.imread(str(img_path))

            if img_bgr is not None:
                # Ensure frame is correct size
                if img_bgr.shape[:2] != (H, W):
                    img_bgr = cv2.resize(img_bgr, (W, H))

                writer.write(img_bgr)
                frame_count += 1
            else:
                print(f"Warning: Could not read {img_file}")

        # Release the writer
        writer.release()

        # Verify file was created
        if os.path.exists(mp4_path_task2):
            file_size_mb = os.path.getsize(mp4_path_task2) / (1024 * 1024)
            print(f"\n✓ Task2 input video created successfully!")
            print(f"  Output: {mp4_path_task2}")
            print(f"  Codec: {codec_used}")
            print(f"  Frames written: {frame_count}/{len(image_files_task2)}")
            print(f"  FPS: {TASK2_VIDEO_FPS}")
            print(f"  Duration: {frame_count/TASK2_VIDEO_FPS:.2f} seconds")
            print(f"  File size: {file_size_mb:.2f} MB")
        else:
            print("ERROR: Video file was not created!")
# Out:
# Found 1050 images in /content/Object_Tracking/Task2/images
# Video dimensions: 1920x1080
# Using codec: MPEG-4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3768765109.py in <cell line: 0>()
#      52         for img_file in image_files_task2:
#      53             img_path = Path(images2_path, img_file)
# ---> 54             img_bgr = cv2.imread(str(img_path))
#      55
#      56             if img_bgr is not None:
#
# KeyboardInterrupt:

# %%
# Step 2: Apply YOLOv8 + BoTSORT Tracking to Task2

from ultralytics import YOLO
import pandas as pd

# Initialize YOLOv8 model using configured parameters
print("Loading YOLOv8 model...")
print(f"  Model: {TASK2_MODEL}")
model = YOLO(TASK2_MODEL)
print("✓ YOLOv8 model loaded")

# Open input video
cap = cv2.VideoCapture(mp4_path_task2)

# Get video properties
fps_input = cap.get(cv2.CAP_PROP_FPS)
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"\nInput Video Properties:")
print(f"  Resolution: {width}x{height}")
print(f"  FPS: {fps_input}")
print(f"  Total frames: {total_frames}")

# Set up output paths
output_path_task2 = os.path.join(A5_savepath, 'task2.mp4')
tracking_results_path_task2 = os.path.join(A5_savepath, 'task2_tracking.txt')

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path_task2, fourcc, fps_input, (width, height))

# Open file to save tracking results
tracking_file = open(tracking_results_path_task2, 'w')

# Process video frame by frame
frame_idx = 0
tracking_data_task2 = []
pedestrian_counts = []  # Store count per frame

print(f"\nProcessing video with YOLOv8 + {TASK2_TRACKER.replace('.yaml', '').upper()}...")
print(f"  Confidence threshold: {TASK2_CONF_THRESHOLD}")
print(f"  IOU threshold: {TASK2_IOU_THRESHOLD}")
print(f"  Max detections: {TASK2_MAX_DET}")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    frame_idx += 1

    # Build tracking parameters dictionary
    track_params = {
        'source': frame,
        'classes': [0],  # Only person class
        'conf': TASK2_CONF_THRESHOLD,
        'iou': TASK2_IOU_THRESHOLD,
        'tracker': TASK2_TRACKER,
        'persist': True,
        'verbose': False,
        'max_det': TASK2_MAX_DET,
        'agnostic_nms': TASK2_AGNOSTIC_NMS,
        'augment': TASK2_AUGMENT
    }

    # Add imgsz if specified
    if TASK2_IMGSZ is not None:
        track_params['imgsz'] = TASK2_IMGSZ

    # Use YOLOv8 built-in tracker with configured parameters
    results = model.track(**track_params)

    # Count people in this frame
    people_count = 0

    # Extract tracking results
    for result in results:
        boxes = result.boxes
        if boxes is not None:
            people_count = len(boxes.xyxy)

        if boxes.id is not None:
            for box_coords, track_id in zip(boxes.xyxy, boxes.id):
                x1, y1, x2, y2 = box_coords.cpu().numpy()
                track_id = int(track_id.cpu().numpy())

                bb_left = int(x1)
                bb_top = int(y1)
                bb_width = int(x2 - x1)
                bb_height = int(y2 - y1)

                # Save tracking result
                tracking_file.write(f"{frame_idx},{track_id},{bb_left},{bb_top},{bb_width},{bb_height}\n")
                tracking_data_task2.append([frame_idx, track_id, bb_left, bb_top, bb_width, bb_height])


                # Draw on frame
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)

                label = f'ID: {track_id}'
                label_size, _ = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)
                label_y = max(int(y1) - 10, label_size[1] + 10)

                cv2.rectangle(frame, (int(x1), label_y - label_size[1] - 10),
                            (int(x1) + label_size[0], label_y), (0, 255, 0), -1)
                cv2.putText(frame, label, (int(x1), label_y - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 2)

    # Store pedestrian count for this frame
    pedestrian_counts.append({'Number': frame_idx, 'Count': people_count})

    # Add frame number and count to video
    cv2.putText(frame, f'Frame: {frame_idx}/{total_frames} | People: {people_count}', (10, 30),
               cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 255), 2)

    out.write(frame)

    if frame_idx % 100 == 0:
        print(f"  Processed frame {frame_idx}/{total_frames} ({frame_idx/total_frames*100:.1f}%)")

cap.release()
out.release()
tracking_file.close()

print(f"\n✓ Part 4 Tracking Complete!")
print(f"  Output video: {output_path_task2}")
print(f"  Tracking results: {tracking_results_path_task2}")
print(f"  Total frames processed: {frame_idx}")
print(f"  Total tracked detections: {len(tracking_data_task2)}")

# Step 3: Export pedestrian counts to CSV for Kaggle
csv_path = os.path.join(A5_savepath, 'task2_count.csv')

# Create DataFrame and export
count_df = pd.DataFrame(pedestrian_counts)
count_df.to_csv(csv_path, index=False)

print(f"\n✓ Pedestrian count CSV exported!")
print(f"  CSV file: {csv_path}")
print(f"  Total frames: {len(count_df)}")
print(f"  Average pedestrians per frame: {count_df['Count'].mean():.2f}")
print(f"  Max pedestrians in a frame: {count_df['Count'].max()}")
print(f"  Min pedestrians in a frame: {count_df['Count'].min()}")

# Display sample of counts
print("\nSample counts (first 10 frames):")
print(count_df.head(10).to_string(index=False))

# %%
  # Submit to Kaggle Competition

  import datetime
  import shutil

  # Rename task2_count.csv to submission.csv for Kaggle
  submission_path = os.path.join(A5_savepath, 'submission.csv')
  task2_count_path = os.path.join(A5_savepath, 'task2_count.csv')

  # Copy task2_count.csv to submission.csv
  if os.path.exists(task2_count_path):
      shutil.copy(task2_count_path, submission_path)
      print(f"✓ Created submission.csv from task2_count.csv")
      print(f"  File: {submission_path}")
  else:
      print(f"ERROR: {task2_count_path} not found!")
      print("Please run the Task 2 tracking cell first to generate task2_count.csv")

  # Submit to Kaggle
  if os.path.exists(submission_path):
      # Generate submission message with timestamp
      timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
      message = f"Submission at {timestamp}"

      print(f"\nSubmitting to Kaggle competition...")
      print(f"  Competition: ecse-415-video-analysis")
      print(f"  File: submission.csv")
      print(f"  Message: {message}")

      # Submit using Kaggle CLI
      # !kaggle competitions submit -c ecse-415-video-analysis -f {submission_path} -m "{message}"

      print(f"\n✓ Submission complete!")
      print(f"  Check your submission status at:")
      print(f"  https://www.kaggle.com/competitions/ecse-415-video-analysis/submissions")
  else:
      print("ERROR: submission.csv not found. Cannot submit to Kaggle.")
